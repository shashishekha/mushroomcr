# %% [markdown]
# ## Import the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Loading the mushrooms.csv file

# %%
df = pd.read_csv("mushrooms.csv")

# %%
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %% [markdown]
# ## print shape of df with rows and columns

# %%
print(df.shape)
# Out:
# (8124, 23)

# %% [markdown]
# ## DATA ANALYSIS

# %% [markdown]
# 1. Missing values
# 2. All the numerical variables
# 3. Distribution of the numerical variables
# 4. Categorical Variables
# 5. Outliers
# 6. Relationship between independent and dependent features
# 7. Correlations

# %%
#Missing values
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
## There are no missing values or null value

# %% [markdown]
# ## Numerical variables

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
df['class'].dtypes =='O'
# Out:
# True

# %%
## There is no numerical values

# %%
df['class'].unique()
# Out:
# array(['p', 'e'], dtype=object)

# %%
count = df['class'].value_counts()

# %%
plt.figure(figsize=(8,7))
sns.barplot(count.index, count.values, alpha=0.8, palette = "prism")
plt.ylabel('Count', fontsize=12)
plt.xlabel('Class', fontsize = 12)
plt.title('Number of poisonous or edible mushrooms')
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# The dataset is balanced

# %% [markdown]
# ## Here the mushroom is either poisonous or edible.

# %%
df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# ...

# %% [markdown]
# The values are in strings so we need to convert them into integers. For that we will perform label encoding.

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
for ele in df.columns:
    df[ele] = labelencoder.fit_transform(df[ele])

df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# ...

# %% [markdown]
# Now the values are encoded

# %%
df['stalk-color-above-ring'].unique()
# Out:
# array([7, 3, 6, 4, 0, 2, 5, 1, 8])

# %%
print(df.groupby('class').size())
# Out:
# class
# 0    4208
# 1    3916
# dtype: int64

# %%
X = df.iloc[:,1:23]
Y = df.iloc[:, 0]
X.head()
Y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# Name: class, dtype: int32

# %%
X.describe()
# Out:
#          cap-shape  cap-surface    cap-color      bruises         odor  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      3.348104     1.827671     4.504677     0.415559     4.144756
# std       1.604329     1.229873     2.545821     0.492848     2.103729
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000     0.000000     3.000000     0.000000     2.000000
# 50%       3.000000     2.000000     4.000000     0.000000     5.000000
# 75%       5.000000     3.000000     8.000000     1.000000     5.000000
# max       5.000000     3.000000     9.000000     1.000000     8.000000
#
#        gill-attachment  gill-spacing    gill-size   gill-color  stalk-shape  \
# count      8124.000000   8124.000000  8124.000000  8124.000000  8124.000000
# mean          0.974151      0.161497     0.309207     4.810684     0.567208
# std           0.158695      0.368011     0.462195     3.540359     0.495493
# ...

# %%
Y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# Name: class, dtype: int32

# %%
df.corr()
# Out:
#                              class  cap-shape  cap-surface  cap-color  \
# class                     1.000000   0.052951     0.178446  -0.031384
# cap-shape                 0.052951   1.000000    -0.050454  -0.048203
# cap-surface               0.178446  -0.050454     1.000000  -0.019402
# cap-color                -0.031384  -0.048203    -0.019402   1.000000
# bruises                  -0.501530  -0.035374     0.070228  -0.000764
# odor                     -0.093552  -0.021935     0.045233  -0.387121
# gill-attachment           0.129200   0.078865    -0.034180   0.041436
# gill-spacing             -0.348387   0.013196    -0.282306   0.144259
# gill-size                 0.540024   0.054050     0.208100  -0.169464
# gill-color               -0.530566  -0.006039    -0.161017   0.084659
# stalk-shape              -0.102019   0.063794    -0.014123  -0.456496
# stalk-root               -0.379361   0.030191    -0.126245   0.321274
# ...

# %% [markdown]
# Standardising the data

# %% [markdown]
# Using StandardScaler to scale the data b/w 1 and -1

# %%
from sklearn.preprocessing import StandardScaler
Scaler = StandardScaler()
X = Scaler.fit_transform(X)
X
# Out:
# array([[ 1.02971224,  0.14012794, -0.19824983, ..., -0.67019486,
#         -0.5143892 ,  2.03002809],
#        [ 1.02971224,  0.14012794,  1.76587407, ..., -0.2504706 ,
#         -1.31310821, -0.29572966],
#        [-2.08704716,  0.14012794,  1.37304929, ..., -0.2504706 ,
#         -1.31310821,  0.86714922],
#        ...,
#        [-0.8403434 ,  0.14012794, -0.19824983, ..., -1.50964337,
#         -2.11182722,  0.28570978],
#        [-0.21699152,  0.95327039, -0.19824983, ...,  1.42842641,
#          0.28432981,  0.28570978],
#        [ 1.02971224,  0.14012794, -0.19824983, ...,  0.16925365,
#         -2.11182722,  0.28570978]])

# %% [markdown]
# Principal Component Analysis

# %%
from sklearn.decomposition import PCA
pca = PCA()
pca.fit_transform(X)
# Out:
# array([[-5.74321902e-01, -9.75781349e-01, -1.22176154e+00, ...,
#         -2.08581362e-01,  8.13996758e-03, -1.02044833e-17],
#        [-2.28210230e+00,  2.79066333e-01, -1.20049669e+00, ...,
#          1.52238789e-01, -1.96446132e-01,  2.79112720e-17],
#        [-1.85803562e+00, -2.70972362e-01, -1.37237069e+00, ...,
#          2.57581784e-01, -3.62577199e-01,  1.23817760e-17],
#        ...,
#        [-1.62151632e+00, -7.57536709e-01,  2.73357994e+00, ...,
#         -1.42532241e+00,  6.36990122e-01,  4.49587834e-19],
#        [ 3.67060561e+00, -1.03277450e+00,  1.68459501e-01, ...,
#          9.41440123e-02, -6.43462238e-02, -2.55402946e-20],
#        [-1.57520272e+00, -1.22858140e+00,  2.44722789e+00, ...,
#         -8.04626064e-01,  5.90315263e-01,  4.76733069e-20]])

# %% [markdown]
# covariance

# %%
covariance = pca.get_covariance()

# %%
explainvar = pca.explained_variance_
explainvar
# Out:
# array([3.87410924e+00, 2.60339434e+00, 2.40073834e+00, 2.16674719e+00,
#        1.70303181e+00, 1.39495575e+00, 9.78803667e-01, 9.51936841e-01,
#        7.70036405e-01, 7.11748353e-01, 5.77556532e-01, 5.42484855e-01,
#        5.09631267e-01, 4.77214086e-01, 3.84467203e-01, 3.11228233e-01,
#        2.18649656e-01, 1.59514884e-01, 1.31521687e-01, 7.31993474e-02,
#        6.16155691e-02, 3.24780638e-34])

# %%
with plt.style.context('dark_background'):
    plt.figure(figsize=(6,4))
    
    plt.bar(range(22), explainvar, alpha=0.5, align='center', label='individual explained variance')
    plt.ylabel('Explained variance ratio')
    plt.xlabel('Principal components')
    plt.legend(loc='best')
    plt.tight_layout()

# %% [markdown]
# The 1st 17 components has less amount of variance of the data. That is the they contain maximum percentange of data.

# %%
pca_modified= PCA(n_components=17)
pca_modified.fit_transform(X)
# Out:
# array([[-0.5743219 , -0.97578135, -1.22176154, ..., -0.51996599,
#         -0.78254366,  1.12025933],
#        [-2.2821023 ,  0.27906633, -1.20049669, ..., -0.11307822,
#         -0.73093408, -0.01817413],
#        [-1.85803562, -0.27097236, -1.37237069, ...,  0.01652548,
#         -0.6561675 ,  0.10791396],
#        ...,
#        [-1.62151632, -0.75753671,  2.73357994, ..., -0.51961303,
#         -0.70768708,  0.22578534],
#        [ 3.67060561, -1.0327745 ,  0.1684595 , ..., -0.08688401,
#         -0.11464249, -0.14801392],
#        [-1.57520272, -1.2285814 ,  2.44722789, ...,  0.91606764,
#         -0.77988482, -0.30141893]])

# %% [markdown]
# Splitting the data into trainig and testing

# %% [markdown]
# ## DECISION TREE CLASSIFICATION

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state = 4)

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()
dt.fit(X_train, Y_train)
print("Test Accuracy: {}%".format(round(dt.score(X_test, Y_test)*100,2)))
# Out:
# Test Accuracy: 100.0%

# %% [markdown]
# ## LOGISTIC REGRESSION CLASSIFICATION

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(solver='lbfgs', max_iter=500)
lr.fit(X_train, Y_train)
print("Test Accuracy: {}%".format(round(lr.score(X_test, Y_test)*100,2)))
# Out:
# Test Accuracy: 95.94%

# %% [markdown]
# ## KNN CLASSIFICATION

# %%
from sklearn.neighbors import KNeighborsClassifier
best_Kvalue = 0
best_score = 0

for i in range(1,10):
    knn = KNeighborsClassifier(n_neighbors = i)
    knn.fit(X_train, Y_train)
    if knn.score(X_test, Y_test)> best_score:
        best_score = knn.score(X_train, Y_train)
        best_Kvalue = i
print("Best KNN Value: {}".format(best_Kvalue))
print("Test Accuracy: {}%".format(round(best_score*100,2)))
# Out:
# Best KNN Value: 1
# Test Accuracy: 100.0%

# %% [markdown]
# ## SVM CLASSIFICATION

# %%
from sklearn.svm import SVC
svm = SVC(random_state=42, gamma="auto")
svm.fit(X_train, Y_train)
print("Test Accuracy: {}%".format(round(svm.score(X_test, Y_test)*100,2)))
# Out:
# Test Accuracy: 100.0%

# %% [markdown]
# ## NAIVE BAYES

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()
nb.fit(X_train, Y_train)

print("Test Accuracy: {}%".format(round(nb.score(X_test, Y_test)*100, 2)))
# Out:
# Test Accuracy: 93.17%

# %% [markdown]
# ## RANDOM FOREST CLASSIFICATION

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, Y_train)

print("Test Accuracy: {}%".format(round(rf.score(X_test, Y_test)*100, 2)))
# Out:
# Test Accuracy: 100.0%

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Most of the4 classification methods hit 100 percent accuracy with the given dataset.
